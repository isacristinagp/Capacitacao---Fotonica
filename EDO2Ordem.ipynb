# %%
import numpy as np
import matplotlib.pyplot as plt
import math

def solucao_analitica(t):
  A = 1
  B = 0
  return A*np.cos(2*t)+B*np.sin(2*t)

h = 0.1
w=2
ti = 0
tf = 10
y0 = 1
y1 = y0
y = [y0, y1]
t = [ti, ti+h]
y_an = [solucao_analitica(t[0]), solucao_analitica(t[1])]

num_step = int((tf-ti)/h)
for i in np.arange(1, num_step):
  t_proximo = t[i]+h
  y_proximo = y[i]*(2-h**2*w**2) - y[i-1]
  y_an_prox = solucao_analitica(t_proximo)

  y.append(y_proximo)
  t.append(t_proximo)
  y_an.append(y_an_prox)

plt.figure(figsize=(8, 5))
plt.plot(t, y, label = 'Solução numérica', linewidth=3)
plt.plot(t, y_an, label='Solução analítica', linewidth=3, linestyle='--')
plt.legend()
plt.title('Solução numérica para y_(n+1)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

def solucao_analitica(t):
  A = 1
  B = 0
  return A*np.cos(2*t)+B*np.sin(2*t)


def solucao_numerica(h):
  w=2
  ti = 0
  tf = 10
  y0 = 1
  y1 = y0
  y = [y0, y1]
  t = [ti, ti+h]
  y_an = [solucao_analitica(t[0]), solucao_analitica(t[1])]
  erro = [(y_an[0]-y[0])**2, (y_an[1]-y[1])**2]

  num_step = int((tf-ti)/h)
  for i in np.arange(1, num_step):
    t_proximo = t[i]+h
    y_proximo = y[i]*(2-h**2*w**2) - y[i-1]
    y_an_prox = solucao_analitica(t_proximo)
    erro.append((y_an_prox-y_proximo)**2)


    y.append(y_proximo)
    t.append(t_proximo)
    y_an.append(y_an_prox)

  plt.figure(figsize=(8, 5))
  plt.plot(t, y, label = 'Solução numérica', linewidth=3)
  plt.plot(t, y_an, label='Solução analítica', linewidth=3, linestyle='--')
  plt.show

  erro_total = 0
  for i in erro:
    erro_total+=i

  e = math.sqrt(erro_total)/num_step

  return e
h1 = 0.1
h2 = 0.2
e1 = solucao_numerica(h1)
e2 = solucao_numerica(h2)

r = math.log(e2-e1)/math.log(h2-h1)

print(r)
# Out:
# 2.083547165827633

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

def solucao_analitica(t):
  A = 1
  B = 0
  return A*np.cos(2*t)+B*np.sin(2*t)

h = 0.1
w=2
ti = 0
tf = 10
y0 = 1
y1 = y0
y = [y0, y1]
t = [ti, ti+h]
y_an = [solucao_analitica(t[0]), solucao_analitica(t[1])]

num_step = int((tf-ti)/h)
for i in np.arange(1, num_step):
  t_proximo = t[i]+h
  y_proximo = y[i]*(2-h**2*w**2) - y[i-1]
  y_an_prox = solucao_analitica(t_proximo)

  y.append(y_proximo)
  t.append(t_proximo)
  y_an.append(y_an_prox)


y_n = [y[0]]
for n in range(1, len(y)-1):
  y_atual = (y[n+1]+y[n-1])/(2 - h**2 * w**2)
  y_n.append(y_atual)
y_n.append(y[-1])

plt.figure(figsize=(8, 5))
plt.plot(t, y, label = 'Solução numérica y_(n+1)', linewidth=3)
plt.plot(t, y_n, label = 'Solução numérica y_n', linewidth=3)
plt.plot(t, y_an, label='Solução analítica', linewidth=3, linestyle='--')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

def solucao_analitica(t):
  A = 1
  B = 0
  return A*np.cos(2*t)+B*np.sin(2*t)

h = 0.1
w=2
ti = 0
tf = 10
y0 = 1
y1 = y0
y = [y0, y1]
t = [ti, ti+h]
y_an = [solucao_analitica(t[0]), solucao_analitica(t[1])]

num_step = int((tf-ti)/h)
for i in np.arange(1, num_step):
  t_proximo = t[i]+h
  y_proximo = y[i]*(2-h**2*w**2) - y[i-1]
  y_an_prox = solucao_analitica(t_proximo)

  y.append(y_proximo)
  t.append(t_proximo)
  y_an.append(y_an_prox)


y_n1 = [y[0]]
for n in range(1, len(y)-1):
  y_anterior = y[n]*(2 - h**2 * w**2) - y[n+1]
  y_n1.append(y_anterior)
y_n1.append(y[-1])

plt.figure(figsize=(8, 5))
plt.plot(t, y, label = 'Solução numérica y_(n-1)', linewidth=3)
plt.plot(t, y_n, label = 'Solução numérica y_n', linewidth=3)
plt.plot(t, y_an, label='Solução analítica', linewidth=3, linestyle='--')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
