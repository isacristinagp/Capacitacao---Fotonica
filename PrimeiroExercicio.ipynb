# %%
import numpy as np
import matplotlib.pyplot as plt

def analytical_solution(x):
    pi_sq_plus_1 = np.pi**2 + 1
    C = 1 + np.pi / pi_sq_plus_1

    return C * np.exp(-x) + (1 / pi_sq_plus_1) * (np.sin(np.pi * x) - np.pi * np.cos(np.pi * x))

def derivada(x,y):
  return np.sin(np.pi*x)-y

x_0 = 0
y_0 = 1
h = 0.01
xf = 10

x = [x_0]
y = [y_0]

y_1 = h*derivada(x_0, y_0) + y_0
x_1 = x_0 + h

x.append(x_1)
y.append(y_1)

num_steps = int((xf-x_0)/h)
for i in np.arange(1, num_steps):
  x_proximo = x[i] + h
  y_proximo = 2*h*derivada(x[i], y[i]) + y[i-1]

  y.append(y_proximo)
  x.append(x_proximo)

x_an = np.linspace(x0, xf, 500)
y_an = analytical_solution(x_an)


plt.plot(x,y, label='Solução Numérica')
plt.plot(x_an, y_an, label='Solução Analítica')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
